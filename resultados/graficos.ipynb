# %%
import matplotlib.pyplot as plt

# Set the x-axis values
x = list(range(4,12))

# sequencial
y1 = [0.000013,0.000047,0.000300,0.002314,0.021432,0.233464,2.690550,31.923984]

# paralelo com 1 nucleo
y2 = [0.011651, 0.010237, 0.010840, 0.021629, 0.137969, 1.351842, 16.470508, 235.741268]

# paralelo com 2 nucleos
y3 = [0.010040,
0.013960,
0.010622,
0.016841,
0.074784,
0.840520,
8.277937,
109.205258]

# paralelo com 4 nucleos
y4 = [0.021180,
0.020988,
0.022357,
0.024273,
0.057112,
0.361798,
4.137515,
57.217389]

# paralelo com 8 nucleos
y5 =[0.043141,
0.042561,
0.042829,
0.041321,
0.083171,
0.574849,
2.840336,
49.471461]

# paralelo com 16 nucleos
y6 = [0.031950,
0.032260,
0.033123,
0.032931,
0.039951,
0.150730,
1.502707,
19.314552]

# paralelo com 32 nucleos
y7 = [0.033139,
0.032473,
0.032801,
0.033788,
0.038643,
0.088443,
0.748798,
12.529849]

# Create a figure and set the size
fig = plt.figure(figsize=(8, 6))

# Add a subplot and set the title
ax = fig.add_subplot(111, title='Sequential vs Parallel with different number of cores')

# Plot the first line using the first set of y-axis values
ax.plot(x, y1, color='b', linestyle='-', marker='o', label='Sequential')

# Plot the second line using the second set of y-axis values
ax.plot(x, y2, color='r', linestyle='--', marker='x', label='Parallel with 1 core')

ax.plot(x, y3, color='g', linestyle='--', marker='x', label='Parallel with 2 core')

ax.plot(x, y4, color='c', linestyle='-.', marker='x', label='Parallel with 4 core')

ax.plot(x, y5, color='m', linestyle='-.', marker='x', label='Parallel with 8 core')

ax.plot(x, y6, color='y', linestyle='-.', marker='x', label='Parallel with 16 core')

ax.plot(x, y7, color='k', linestyle='-.', marker='x', label='Parallel with 32 core')

# Add a legend
ax.legend(loc='upper left')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import numpy as np
# Set the x-axis values
x = list(range(9,12))

# sequencial
y1 = [0.000013,0.000047,0.000300,0.002314,0.021432,0.233464,2.690550,31.923984]

# paralelo com 1 nucleo
y2 = [0.011651, 0.010237, 0.010840, 0.021629, 0.137969, 1.351842, 16.470508, 235.741268]

# paralelo com 2 nucleos
y3 = [0.010040,
0.013960,
0.010622,
0.016841,
0.074784,
0.840520,
8.277937,
109.205258]

# paralelo com 4 nucleos
y4 = [0.021180,
0.020988,
0.022357,
0.024273,
0.057112,
0.361798,
4.137515,
57.217389]

# paralelo com 8 nucleos
y5 =[0.043141,
0.042561,
0.042829,
0.041321,
0.083171,
0.574849,
2.840336,
49.471461]

# paralelo com 16 nucleos
y6 = [0.031950,
0.032260,
0.033123,
0.032931,
0.039951,
0.150730,
1.502707,
19.314552]

# paralelo com 32 nucleos
y7 = [0.033139,
0.032473,
0.032801,
0.033788,
0.038643,
0.088443,
0.748798,
12.529849]


# y1= y1[9:]
# y2= y2[9:]
# y3= y3[9:]
# y4= y4[9:]
# y5= y5[9:]
# y6= y6[9:]
# y7= y7[9:]

def get_last_four(my_list):
  # Get the length of the list
  length = len(my_list)

  # Return the last four elements of the list
  return my_list[length-3:length]

y1 = get_last_four(y1)
y2 = get_last_four(y2)
y3 = get_last_four(y3)
y4 = get_last_four(y4)
y5 = get_last_four(y5)
y6 = get_last_four(y6)
y7 = get_last_four(y7)


# Create a figure and set the size
fig = plt.figure(figsize=(8, 6))

# Add a subplot and set the title
ax = fig.add_subplot(111, title='Sequential vs Parallel with different number of cores')

# Plot the first line using the first set of y-axis values
ax.plot(x, y1, color='b', linestyle='-', marker='o', label='Sequential')

# Plot the second line using the second set of y-axis values
ax.plot(x, y2, color='r', linestyle='--', marker='o', label='Parallel with 1 core')

ax.plot(x, y3, color='g', linestyle='--', marker='o', label='Parallel with 2 core')

ax.plot(x, y4, color='c', linestyle='-.', marker='o', label='Parallel with 4 core')

ax.plot(x, y5, color='m', linestyle='-.', marker='o', label='Parallel with 8 core')

ax.plot(x, y6, color='y', linestyle='-.', marker='o', label='Parallel with 16 core')

ax.plot(x, y7, color='k', linestyle='-.', marker='o', label='Parallel with 32 core')

alogrithms = [y1, y2, y3, y4, y5, y6, y7]

for i in alogrithms:
  ax.annotate(f'   ({i[2]})', (x[2], i[2]))

# Add a legend
ax.legend(loc='upper left')

# Show the plot
plt.show()
